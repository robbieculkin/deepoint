# %%
import numpy as np
import matplotlib.pyplot as plt
from src.image_generator import generate_images
# Out:
# pygame 2.0.0.dev6 (SDL 2.0.10, python 3.7.3)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
g= generate_images(object_types=['star'],display_mode=1, shape=(160,120))

# %%
for ii in range(2):
    x,y = next(g)
    plt.imshow(x[0], cmap='gray')
    plt.show()
    plt.imshow(y[0], cmap='gray',)
    plt.show()
# Out:
# [INFO] rendering image 0/1
# [INFO] rendering image 1/1
# [INFO] rendering image 0/1
# [INFO] rendering image 1/1
